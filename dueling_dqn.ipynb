# %%
import gymnasium as gym
from dqn_agent import DQN_Agent
from agent_handler import Agent_handler as AgentHandler
from dueling_dqn.agent import DuelingDQN_Agent
from dueling_dqn.utils import describe_env, plot_results
# Out:
# 2023-11-19 17:11:02.945531: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### 1. Initialize Pacman Environment

# %%
env = gym.make("MsPacman-v4")
num_obs, num_actions = describe_env(env)
# Out:
# Observation space:  Box(0, 255, (210, 160, 3), uint8)
# Observation space size:  (210, 160, 3)
# Number of actions:  9
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
handler = AgentHandler(
    {"num_episodes": 20, "max_steps": 10000, "notify_percent": 5, "update_rate": 10}
)

# %% [markdown]
# #### 2. Train DQN Agent for comparison

# %%
dqn_agent = DQN_Agent(
    {
        "num_obs": num_obs,
        "num_actions": num_actions,
        "learning_rate": 0.01,
        "discount_factor": 0.9,
        "exploration_factor": 0.2,
    }
)

results = handler.train([dqn_agent], env)
plot_results(results, "DQN Agent", 1)
# Out:
# 2023-11-19 17:03:14.217727: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-11-19 17:03:14.217776: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ~~~ Training Agent 1 1/1 ~~~
# 	Episode 0/20 0%
# 2023-11-19 17:03:14.548667: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-19 17:03:39.313870: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-19 17:03:39.868081: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-19 17:03:39.921757: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp_10.
# End of episode, n_steps: 906
# 	Episode 1/20 5%
# End of episode, n_steps: 608
# 	Episode 2/20 10%
# End of episode, n_steps: 427
# 	Episode 3/20 15%
# End of episode, n_steps: 404
# 	Episode 4/20 20%
# End of episode, n_steps: 687
# 	Episode 5/20 25%
# End of episode, n_steps: 651
# 	Episode 6/20 30%
# End of episode, n_steps: 494
# 	Episode 7/20 35%
# End of episode, n_steps: 671
# 	Episode 8/20 40%
# End of episode, n_steps: 857
# 	Episode 9/20 45%
# End of episode, n_steps: 913
# 	Episode 10/20 50%
# End of episode, n_steps: 854
# 	Episode 11/20 55%
# End of episode, n_steps: 505
# 	Episode 12/20 60%
# End of episode, n_steps: 790
# 	Episode 13/20 65%
# End of episode, n_steps: 655
# 	Episode 14/20 70%
# End of episode, n_steps: 765
# 	Episode 15/20 75%
# End of episode, n_steps: 1000
# 	Episode 16/20 80%
# End of episode, n_steps: 488
# 	Episode 17/20 85%
# End of episode, n_steps: 928
# 	Episode 18/20 90%
# End of episode, n_steps: 909
# 	Episode 19/20 95%
# End of episode, n_steps: 716
# 	Episode 20/20 100%
#
# Done training!

# %% [markdown]
# #### 3. Train Dueling DQN Agent

# %%
dueling_dqn_agent = DuelingDQN_Agent(
    {
        "num_obs": num_obs,
        "num_actions": num_actions,
        "learning_rate": 0.05,
        "discount_factor": 0.9,
        "exploration_factor": 0.2,
    }
)
results = handler.train([dueling_dqn_agent], env)
plot_results(results, "Dueling DQN Agent", 1)
# Out:
# 2023-11-19 17:11:15.188056: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-11-19 17:11:15.188114: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ~~~ Training Agent 1 1/1 ~~~
# 	Episode 0/20 0%
# 2023-11-19 17:11:15.623047: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-19 17:11:34.967493: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-19 17:11:35.674545: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-19 17:11:35.745784: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp_10.
# End of episode, n_steps: 667
# 	Episode 1/20 5%
# End of episode, n_steps: 1444
# 	Episode 2/20 10%
# End of episode, n_steps: 994
# 	Episode 3/20 15%
# End of episode, n_steps: 1229
# 	Episode 4/20 20%
# End of episode, n_steps: 720
# 	Episode 5/20 25%
# End of episode, n_steps: 824
# 	Episode 6/20 30%
# End of episode, n_steps: 796
# 	Episode 7/20 35%
# End of episode, n_steps: 785
# 	Episode 8/20 40%
# End of episode, n_steps: 946
# 	Episode 9/20 45%
# End of episode, n_steps: 783
# 	Episode 10/20 50%
# End of episode, n_steps: 917
# 	Episode 11/20 55%
# End of episode, n_steps: 720
# 	Episode 12/20 60%
# End of episode, n_steps: 739
# 	Episode 13/20 65%
# End of episode, n_steps: 780
# 	Episode 14/20 70%
# End of episode, n_steps: 789
# 	Episode 15/20 75%
# End of episode, n_steps: 690
# 	Episode 16/20 80%
# End of episode, n_steps: 643
# 	Episode 17/20 85%
# End of episode, n_steps: 746
# 	Episode 18/20 90%
# End of episode, n_steps: 767
# 	Episode 19/20 95%
# End of episode, n_steps: 687
# 	Episode 20/20 100%
#
# Done training!
