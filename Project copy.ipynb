# %%
import utils as Utils
from dqn_agent import DQN_Agent
from agent_handler import Agent_handler
from double_dqn_agent import Double_DQN_Agent
from dueling_dqn_agent import DuelingDQN_Agent
from assignment3_utils import *
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import gym

# %%
env = gym.make('PongDeterministic-v4', render_mode='rgb_array')

num_obs, num_actions = Utils.describe_env(env)
# Out:
# Observation space:  Box(0, 255, (210, 160, 3), uint8)
# Observation space size:  (210, 160, 3)
# Number of actions:  6

# %%
agents = []

obs = (4, 84, 70, 1)

batch = 8
update = 10
options = {
  "num_obs": obs,
  "num_actions": num_actions,
  "update_rate": update,
  "learning_rate": 0.0001,
  "discount_factor": 0.95,
  "exploration_factor": 1,
  "min_exploration_rate": 0.05,
  "exploration_decay": 0.995,
  "batch_size": batch,
  "name": f'{batch}_{update}'
}
agents.append(DQN_Agent(options))

batch = 16
update = 10
options = {
  "num_obs": obs,
  "num_actions": num_actions,
  "update_rate": update,
  "learning_rate": 0.0001,
  "discount_factor": 0.95,
  "exploration_factor": 1,
  "min_exploration_rate": 0.05,
  "exploration_decay": 0.995,
  "batch_size": batch,
  "name": f'{batch}_{update}'
}
agents.append(DQN_Agent(options))

batch = 8
update = 3
options = {
  "num_obs": obs,
  "num_actions": num_actions,
  "update_rate": update,
  "learning_rate": 0.0001,
  "discount_factor": 0.95,
  "exploration_factor": 1,
  "min_exploration_rate": 0.05,
  "exploration_decay": 0.995,
  "batch_size": batch,
  "name": f'{batch}_{update}'
}
agents.append(DQN_Agent(options))

batch = 16
update = 3
options = {
  "num_obs": obs,
  "num_actions": num_actions,
  "update_rate": update,
  "learning_rate": 0.0001,
  "discount_factor": 0.95,
  "exploration_factor": 1,
  "min_exploration_rate": 0.05,
  "exploration_decay": 0.995,
  "batch_size": batch,
  "name": f'{batch}_{update}'
}
agents.append(DQN_Agent(options))

# %%
handler = Agent_handler({
    "num_episodes":1,
    "max_steps":1,
    "notify_percent":1,
    "skip": 15,
    "checkpoint_interval": 500,
    "crop": {
      "top": 33,
      "bottom": -16,
      "left": 20,
      "right": -1,
  }
})

# %%
results = handler.train([agents[0]], env)
# Out:
# ~~~ Training Agent: 1/1 ~~~
# 	Name	: 8_10
# 	Start	: 11-26 23:31
#
# 	Episode	: 0/1 0%
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# Original Image Shape: (210, 160, 3)
# Cropped Image Shape: (161, 139, 3)
# Downsampled Image Shape: (81, 70, 3)
# Grayscale Image Shape: (81, 70)
# Normalized Image Shape: (81, 70)
# 	Better	: 0.0 ~ 11-26 23:31
#
# 	Done	: 11-26 23:31
#
# Done training!

# %%
window_size = 100

for agent, result in results.items():
  moving_average = np.convolve(result["rewards"], np.ones(window_size)/window_size, mode='valid')

  padding = np.full(5 - 1, 0)
  result_array = np.concatenate([padding, moving_average])
  result["rewards averages"] = result_array
  Utils.plot_results(result, agent)
